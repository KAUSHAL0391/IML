# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture

np.random.seed(42)

cluster1 = np.random.multivariate_normal(mean=[2, 2], cov=[[1, 0.5], [0.5, 1]], size=150)

cluster2 = np.random.multivariate_normal(mean=[8, 8], cov=[[1, -0.5], [-0.5, 1]], size=150)

synthetic_data = np.concatenate([cluster1, cluster2])

gmm = GaussianMixture(n_components=2, random_state=42)
gmm.fit(synthetic_data)
predicted_labels = gmm.predict(synthetic_data)
means = gmm.means_
covariances = gmm.covariances_

plt.scatter(synthetic_data[:, 0], synthetic_data[:, 1], c=predicted_labels, cmap='viridis')
plt.scatter(means[:, 0], means[:, 1], marker='X', s=200, c='red', label='Centroids')
plt.title('EM Algorithm Clustering on Synthetic Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
